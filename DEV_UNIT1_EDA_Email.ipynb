# %%
# Reference:
# Suresh Kumar Mukhiya, Usman Ahmed, “Hands-On Exploratory Data Analysis with Python”, Packt Publishing, 2020
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# %%
import mailbox
mboxfile = "/content/drive/My Drive/DEA/MyEmailbox2.mbox"
mbox = mailbox.mbox(mboxfile)
mbox

# %%
for key in mbox[0].keys():
  print(key)
# Out:
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Cc
# Content-Type

# %%
import csv

# %%
with open('mailbox.csv', 'w') as outputfile:
  writer = csv.writer(outputfile)
  writer.writerow(['subject','from','date','to','label','thread','Cc'])
  for message in mbox:
    writer.writerow([
    message['subject'],
    message['from'],
    message['date'],
    message['to'],
    message['X-Gmail-Labels'],
    message['X-GM-THRID'],
    message['Cc']
  ]
)

# %%
dfs = pd.read_csv('mailbox.csv', names=['subject', 'from', 'date', 'to','label', 'thread','Cc'])

# %%
dfs.dtypes
# Out:
# subject    object
# from       object
# date       object
# to         object
# label      object
# thread     object
# Cc         object
# dtype: object

# %%
#converting the date
dfs['date'] = dfs['date'].apply(lambda x: pd.to_datetime(x,errors='coerce', utc=True))

# %%
# Removing NaN values 

dfs = dfs[dfs['date'].notna()]
dfs.to_csv('gmail.csv')

# %%
#Applying descriptive statistics
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 1 to 457
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   subject  450 non-null    object
#  1   from     457 non-null    object
#  2   date     457 non-null    datetime64[ns, UTC]
#  3   to       453 non-null    object
#  4   label    457 non-null    object
#  5   thread   457 non-null    object
#  6   Cc       198 non-null    object
# dtypes: datetime64[ns, UTC](1), object(6)
# memory usage: 28.6+ KB

# %%
dfs.head(10)
# Out:
#                                               subject  \
# 1                                 ISO New Form - reg.
# 2                      Re: Academic audit report -reg
# 3                          Academic audit report -reg
# 4   V and VII semester open Elective list with han...
# 5   Corrected Academic calender -2022-2023-III sel...
# 6   Fwd: CIRCULAR-RIT/Academic/2022-2023/Faculty M...
# 7   CIRCULAR-RIT/Academic/2022-2023/Faculty Meetin...
# 8   suggested additional hours - III semester cour...
# 9                    Share request for "AD 2022-2026"
# 10      Regulation 2021-30th IPDC meeting minutes-reg
#
#                                                  from  \
# 1                      rit iso <ritiso@ritrjpm.ac.in>
# 2            Gnana Priya G <gnanapriya@ritrjpm.ac.in>
# 3   academiccoordinator rit <academiccoordinator@r...
# 4   academiccoordinator rit <academiccoordinator@r...
# 5   ritacademiccoordinator rit <ritacademiccoordin...
# 6   academiccoordinator rit <academiccoordinator@r...
# 7   academiccoordinator rit <academiccoordinator@r...
# 8   academiccoordinator rit <academiccoordinator@r...
# 9   "Anbarasan C (via Google Sheets)" <drive-share...
# 10  academiccoordinator rit <academiccoordinator@r...
#
#                         date  \
# 1  2022-08-25 07:17:41+00:00
# 2  2022-08-16 05:38:05+00:00
# 3  2022-08-16 05:12:23+00:00
# 4  2022-08-08 09:28:53+00:00
# 5  2022-08-25 06:31:56+00:00
# 6  2022-08-10 07:30:04+00:00
# 7  2022-08-05 11:08:25+00:00
# 8  2022-08-22 05:51:45+00:00
# 9  2022-08-03 09:36:14+00:00
# 10 2022-03-28 10:30:22+00:00
#
#                                                    to  \
# 1                               faculty@ritrjpm.ac.in
# 2   academiccoordinator rit <academiccoordinator@r...
# 3              Gnana Priya <gnanapriya@ritrjpm.ac.in>
# 4               yogaraja C A <yogaraja@ritrjpm.ac.in>
# 5                               faculty@ritrjpm.ac.in
# 6                               faculty@ritrjpm.ac.in
# 7                               faculty@ritrjpm.ac.in
# 8   Vijayalakshmi K <vijayalakshmik@ritrjpm.ac.in>...
# 9                   academiccoordinator@ritrjpm.ac.in
# 10  Rajakarunakaran S <rajakarunakaran@ritrjpm.ac.in>
#
#                                        label               thread  \
# 1   Inbox,Important,Opened,Category Personal  1742117101205861237
# 2   Inbox,Important,Opened,Category Personal  1741293705117655457
# 3                       Archived,Sent,Opened  1741293705117655457
# 4                              Archived,Sent  1740585016535255003
# 5                              Archived,Sent  1742113293927196853
# 6                                       Sent  1740319452998108596
# 7                       Archived,Sent,Opened  1740319452998108596
# 8                              Archived,Sent  1741839323012155946
# 9    Important,Trash,Category Updates,Unread  1740132187765759993
# 10                             Archived,Sent  1728539106347794707
#
#                                                    Cc
# 1   principal@ritrjpm.ac.in, vp@ritrjpm.ac.in, \r\...
# 2                                                 NaN
# 3                                                 NaN
# 4   Indhumathi M <indhumathi@ritrjpm.ac.in>, \r\n\...
# 5   Principal <principal@ritrjpm.ac.in>, vice prin...
# 6   Principal <principal@ritrjpm.ac.in>, vice prin...
# 7   Principal <principal@ritrjpm.ac.in>, vice prin...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN

# %%
#Data refactoring
import re
def extract_email_ID(string):
  email = re.findall(r'<(.+?)>', string)
  if not email:
    email = list(filter(lambda y: '@' in y, string.split()))
  return email[0] if email else np.nan

# %%
dfs['from'] = dfs['from'].apply(lambda x: extract_email_ID(x))

# %%
myemail = 'kaliappan@ritrjpm.ac.in'
dfs['label'] = dfs['from'].apply(lambda x: 'sent' if x==myemail else 'inbox')

# %%
#Dropping columns
dfs.drop(columns='to', inplace=True)

# %%
dfs
# Out:
#                                                subject  \
# 1                                  ISO New Form - reg.
# 2                       Re: Academic audit report -reg
# 3                           Academic audit report -reg
# 4    V and VII semester open Elective list with han...
# 5    Corrected Academic calender -2022-2023-III sel...
# ..                                                 ...
# 453    Fwd: IE(I)-ECE-Student handbook-2021 batch-Reg.
# 454    Fwd: IE(I)-ECE-Student handbook-2021 batch-Reg.
# 455    Model Practical lab and Bus Departure Time- reg
# 456    Fwd: II Year Mech - Bridge course Details - Reg
# 457         II Year Mech - Bridge course Details - Reg
#
#                                      from                      date  label  \
# 1                    ritiso@ritrjpm.ac.in 2022-08-25 07:17:41+00:00  inbox
# 2                gnanapriya@ritrjpm.ac.in 2022-08-16 05:38:05+00:00  inbox
# 3       academiccoordinator@ritrjpm.ac.in 2022-08-16 05:12:23+00:00  inbox
# 4       academiccoordinator@ritrjpm.ac.in 2022-08-08 09:28:53+00:00  inbox
# 5    ritacademiccoordinator@ritrjpm.ac.in 2022-08-25 06:31:56+00:00  inbox
# ..                                    ...                       ...    ...
# 453     academiccoordinator@ritrjpm.ac.in 2021-12-15 03:05:22+00:00  inbox
# 454               kaliappan@ritrjpm.ac.in 2021-12-13 12:02:08+00:00   sent
# 455     academiccoordinator@ritrjpm.ac.in 2022-02-21 11:44:15+00:00  inbox
# 456     academiccoordinator@ritrjpm.ac.in 2022-08-08 07:56:51+00:00  inbox
# 457              kathiravan@ritrjpm.ac.in 2022-08-08 05:19:00+00:00  inbox
#
#                   thread                                                 Cc
# 1    1742117101205861237  principal@ritrjpm.ac.in, vp@ritrjpm.ac.in, \r\...
# 2    1741293705117655457                                                NaN
# 3    1741293705117655457                                                NaN
# 4    1740585016535255003  Indhumathi M <indhumathi@ritrjpm.ac.in>, \r\n\...
# 5    1742113293927196853  Principal <principal@ritrjpm.ac.in>, vice prin...
# ..                   ...                                                ...
# 453  1719032286824048724                                                NaN
# 454  1719032286824048724                                                NaN
# 455  1725373351312909515  Principal <principal@ritrjpm.ac.in>, vice prin...
# 456  1740569411833821157                                                NaN
# 457  1740569411833821157  Rajakarunakaran S <rajakarunakaran@ritrjpm.ac....
#
# [457 rows x 6 columns]

# %%
import pytz
def refactor_timezone(x):
  est = pytz.timezone('US/Eastern')
  return x.astimezone(est)

# %%
dfs['date'] = dfs['date'].apply(lambda x: refactor_timezone(x))

# %%
#convert the day of the week variable into the name of the day, as in, Saturday, Sunday, and so on
dfs['dayofweek'] = dfs['date'].apply(lambda x: x.day_name())
dfs['dayofweek'] = pd.Categorical(dfs['dayofweek'], categories=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday', 'Sunday'], ordered=True)

# %%
#same process for the time of the day
dfs['timeofday'] = dfs['date'].apply(lambda x: x.hour + x.minute/60+ x.second/3600)

# %%
dfs['hour'] = dfs['date'].apply(lambda x: x.hour)

# %%
dfs['year_int'] = dfs['date'].apply(lambda x: x.year)

# %%
dfs['year'] = dfs['date'].apply(lambda x: x.year +x.dayofyear/365.25)

# %%
dfs.index = dfs['date']
del dfs['date']

# %%
#EDA
#1. How many emails did I send during a given timeframe?
#2. At what times of the day do I send and receive emails with Gmail?
#3. What is the average number of emails per day?
#4. What is the average number of emails per hour?
#5. Whom do I communicate with most frequently?
#6. What are the most active emailing days?
#7. What am I mostly emailing about?

# %%
#Number of emails
print(dfs.index.min().strftime('%a, %d %b %Y %I:%M %p'))
print(dfs.index.max().strftime('%a, %d %b %Y %I:%M %p'))
print(dfs['label'].value_counts())
# Out:
# Tue, 23 Nov 2021 05:07 AM
# Thu, 01 Sep 2022 04:25 AM
# sent     276
# inbox    181
# Name: label, dtype: int64

# %%
#two sub-dataframe—one for sent emails and another for received emails:
sent = dfs[dfs['label']=='sent']
received = dfs[dfs['label']=='inbox']

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from scipy import ndimage
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

# %%
#create a function that takes a dataframe as an input and creates a plot
def plot_todo_vs_year(df, ax, color='C0', s=0.5, title=''):
  ind = np.zeros(len(df), dtype='bool')
  est = pytz.timezone('US/Eastern')
  df[~ind].plot.scatter('year', 'timeofday', s=s, alpha=0.6, ax=ax,color=color)
  ax.set_ylim(0, 24)
  ax.yaxis.set_major_locator(MaxNLocator(8))
  ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts,24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);
  ax.set_xlabel('')
  ax.set_ylabel('')
  ax.set_title(title)
  ax.grid(ls=':', color='k')
  return ax

# %%
import datetime
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))
plot_todo_vs_year(sent, ax[0], title='Sent')
plot_todo_vs_year(received, ax[1], title='Received')

# %%
#Average emails per day and hour

# %%
def plot_number_perday_per_year(df, ax, label=None, dt=0.3,**plot_kwargs):
  year = df[df['year'].notna()]['year'].values
  T = year.max() - year.min()
  bins = int(T / dt)
  weights = 1 / (np.ones_like(year) * dt * 365.25)
  ax.hist(year, bins=bins, weights=weights, label=label,**plot_kwargs);
  ax.grid(ls=':', color='k')

# %%
#creates a function that plots the average number of emails per day
def plot_number_perdhour_per_year(df, ax, label=None, dt=1,smooth=False,weight_fun=None, **plot_kwargs):
  tod = df[df['timeofday'].notna()]['timeofday'].values
  year = df[df['year'].notna()]['year'].values
  Ty = year.max() - year.min()
  T = tod.max() - tod.min()
  bins = int(T / dt)
  if weight_fun is None:
    weights = 1 / (np.ones_like(tod) * Ty * 365.25 / dt)
  else:
    weights = weight_fun(df)
  if smooth:
    hst, xedges = np.histogram(tod, bins=bins,weights=weights);
    x = np.delete(xedges, -1) + 0.5*(xedges[1] - xedges[0])
    hst = ndimage.gaussian_filter(hst, sigma=0.75)
    f = interp1d(x, hst, kind='cubic')
    x = np.linspace(x.min(), x.max(), 10000)
    hst = f(x)
    ax.plot(x, hst, label=label, **plot_kwargs)
  else:
    ax.hist(tod, bins=bins, weights=weights, label=label,**plot_kwargs);
  ax.grid(ls=':', color='k')
  orientation = plot_kwargs.get('orientation')
  if orientation is None or orientation == 'vertical':
    ax.set_xlim(0, 24)
    ax.xaxis.set_major_locator(MaxNLocator(8))
    ax.set_xticklabels([datetime.datetime.strptime(str(int(np.mod(ts,24))), "%H").strftime("%I %p") for ts in ax.get_xticks()]);
  elif orientation == 'horizontal':
    ax.set_ylim(0, 24)
    ax.yaxis.set_major_locator(MaxNLocator(8))
  ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);

# %%
# create a class that plots the time of the day versus year for all the emails within the given timeframe
class TriplePlot:
  def __init__(self):
    gs = gridspec.GridSpec(6, 6)
    self.ax1 = plt.subplot(gs[2:6, :4])
    self.ax2 = plt.subplot(gs[2:6, 4:6], sharey=self.ax1)
    plt.setp(self.ax2.get_yticklabels(), visible=False);
    self.ax3 = plt.subplot(gs[:2, :4])
    plt.setp(self.ax3.get_xticklabels(), visible=False);
  def plot(self, df, color='darkblue', alpha=0.8, markersize=0.5,yr_bin=0.1, hr_bin=0.5):
    plot_todo_vs_year(df, self.ax1, color=color, s=markersize)
    plot_number_perdhour_per_year(df, self.ax2, dt=hr_bin,color=color, alpha=alpha, orientation='horizontal')
    self.ax2.set_xlabel('Average emails per hour')
    plot_number_perday_per_year(df, self.ax3, dt=yr_bin,color=color, alpha=alpha)
    self.ax3.set_ylabel('Average emails per day')

# %%
#instantiate the class to plot the graph:
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
import datetime
plt.figure(figsize=(12,12));
tpl = TriplePlot()
tpl.plot(received, color='C0', alpha=0.5)
tpl.plot(sent, color='C1', alpha=0.5)
p1 = mpatches.Patch(color='C0', label='Incoming', alpha=0.5)
p2 = mpatches.Patch(color='C1', label='Outgoing', alpha=0.5)
plt.legend(handles=[p1, p2], bbox_to_anchor=[1.45, 0.7],fontsize=14, shadow=True);

# %%
#Number of emails per day

# %%
#find the busiest day of the week in terms of emails:
counts = dfs.dayofweek.value_counts(sort=False)
counts.plot(kind='bar')

# %%
#the most active days for receiving and sending emails separately

# %%
sdw = sent.groupby('dayofweek').size() / len(sent)
rdw = received.groupby('dayofweek').size() / len(received)
df_tmp = pd.DataFrame(data={'Outgoing Email': sdw, 'Incoming Email':rdw})
df_tmp.plot(kind='bar', rot=45, figsize=(8,5), alpha=0.5)
plt.xlabel('');
plt.ylabel('Fraction of weekly emails');
plt.grid(ls=':', color='k', alpha=0.5)

# %%
import matplotlib.pyplot as plt   
import seaborn as sns 
plt.figure(figsize=(10,10))
dfs
# Out:
#                                                                      subject  \
# date
# 2022-08-25 03:17:41-04:00                                ISO New Form - reg.
# 2022-08-16 01:38:05-04:00                     Re: Academic audit report -reg
# 2022-08-16 01:12:23-04:00                         Academic audit report -reg
# 2022-08-08 05:28:53-04:00  V and VII semester open Elective list with han...
# 2022-08-25 02:31:56-04:00  Corrected Academic calender -2022-2023-III sel...
# ...                                                                      ...
# 2021-12-14 22:05:22-05:00    Fwd: IE(I)-ECE-Student handbook-2021 batch-Reg.
# 2021-12-13 07:02:08-05:00    Fwd: IE(I)-ECE-Student handbook-2021 batch-Reg.
# 2022-02-21 06:44:15-05:00    Model Practical lab and Bus Departure Time- reg
# 2022-08-08 03:56:51-04:00    Fwd: II Year Mech - Bridge course Details - Reg
# 2022-08-08 01:19:00-04:00         II Year Mech - Bridge course Details - Reg
#
#                                                            from  label  \
# date
# 2022-08-25 03:17:41-04:00                  ritiso@ritrjpm.ac.in  inbox
# 2022-08-16 01:38:05-04:00              gnanapriya@ritrjpm.ac.in  inbox
# 2022-08-16 01:12:23-04:00     academiccoordinator@ritrjpm.ac.in   sent
# 2022-08-08 05:28:53-04:00     academiccoordinator@ritrjpm.ac.in   sent
# 2022-08-25 02:31:56-04:00  ritacademiccoordinator@ritrjpm.ac.in  inbox
# ...                                                         ...    ...
# 2021-12-14 22:05:22-05:00     academiccoordinator@ritrjpm.ac.in   sent
# 2021-12-13 07:02:08-05:00               kaliappan@ritrjpm.ac.in  inbox
# 2022-02-21 06:44:15-05:00     academiccoordinator@ritrjpm.ac.in   sent
# 2022-08-08 03:56:51-04:00     academiccoordinator@ritrjpm.ac.in   sent
# 2022-08-08 01:19:00-04:00              kathiravan@ritrjpm.ac.in  inbox
#
#                                         thread  \
# date
# 2022-08-25 03:17:41-04:00  1742117101205861237
# 2022-08-16 01:38:05-04:00  1741293705117655457
# 2022-08-16 01:12:23-04:00  1741293705117655457
# 2022-08-08 05:28:53-04:00  1740585016535255003
# 2022-08-25 02:31:56-04:00  1742113293927196853
# ...                                        ...
# 2021-12-14 22:05:22-05:00  1719032286824048724
# 2021-12-13 07:02:08-05:00  1719032286824048724
# 2022-02-21 06:44:15-05:00  1725373351312909515
# 2022-08-08 03:56:51-04:00  1740569411833821157
# 2022-08-08 01:19:00-04:00  1740569411833821157
#
#                                                                           Cc  \
# date
# 2022-08-25 03:17:41-04:00  principal@ritrjpm.ac.in, vp@ritrjpm.ac.in, \r\...
# 2022-08-16 01:38:05-04:00                                                NaN
# 2022-08-16 01:12:23-04:00                                                NaN
# 2022-08-08 05:28:53-04:00  Indhumathi M <indhumathi@ritrjpm.ac.in>, \r\n\...
# 2022-08-25 02:31:56-04:00  Principal <principal@ritrjpm.ac.in>, vice prin...
# ...                                                                      ...
# 2021-12-14 22:05:22-05:00                                                NaN
# 2021-12-13 07:02:08-05:00                                                NaN
# 2022-02-21 06:44:15-05:00  Principal <principal@ritrjpm.ac.in>, vice prin...
# 2022-08-08 03:56:51-04:00                                                NaN
# 2022-08-08 01:19:00-04:00  Rajakarunakaran S <rajakarunakaran@ritrjpm.ac....
#
#                           dayofweek  timeofday  hour  year_int         year
# date
# 2022-08-25 03:17:41-04:00  Thursday   3.294722     3      2022  2022.648871
# 2022-08-16 01:38:05-04:00   Tuesday   1.634722     1      2022  2022.624230
# 2022-08-16 01:12:23-04:00   Tuesday   1.206389     1      2022  2022.624230
# 2022-08-08 05:28:53-04:00    Monday   5.481389     5      2022  2022.602327
# 2022-08-25 02:31:56-04:00  Thursday   2.532222     2      2022  2022.648871
# ...                             ...        ...   ...       ...          ...
# 2021-12-14 22:05:22-05:00   Tuesday  22.089444    22      2021  2021.952772
# 2021-12-13 07:02:08-05:00    Monday   7.035556     7      2021  2021.950034
# 2022-02-21 06:44:15-05:00    Monday   6.737500     6      2022  2022.142368
# 2022-08-08 03:56:51-04:00    Monday   3.947500     3      2022  2022.602327
# 2022-08-08 01:19:00-04:00    Monday   1.316667     1      2022  2022.602327
#
# [457 rows x 10 columns]

# %%
dfs.groupby('label').groups.keys()
# Out:
# dict_keys(['inbox', 'sent'])

# %%
lg = dfs.groupby('label')
counts = lg.label.value_counts(sort=False)
counts.plot(kind='pie')

# %%
# Get values items from group with value sent
se=lg.get_group("sent")
se
# Out:
#                                                                      subject  \
# date
# 2022-08-16 01:12:23-04:00                         Academic audit report -reg
# 2022-08-08 05:28:53-04:00  V and VII semester open Elective list with han...
# 2022-08-10 03:30:04-04:00  Fwd: CIRCULAR-RIT/Academic/2022-2023/Faculty M...
# 2022-08-05 07:08:25-04:00  CIRCULAR-RIT/Academic/2022-2023/Faculty Meetin...
# 2022-08-22 01:51:45-04:00  suggested additional hours - III semester cour...
# ...                                                                      ...
# 2021-12-29 04:10:56-05:00                                                NaN
# 2021-12-27 04:26:30-05:00       Consolidated Marks Statement for Unit Test-I
# 2021-12-14 22:05:22-05:00    Fwd: IE(I)-ECE-Student handbook-2021 batch-Reg.
# 2022-02-21 06:44:15-05:00    Model Practical lab and Bus Departure Time- reg
# 2022-08-08 03:56:51-04:00    Fwd: II Year Mech - Bridge course Details - Reg
#
#                                                         from label  \
# date
# 2022-08-16 01:12:23-04:00  academiccoordinator@ritrjpm.ac.in  sent
# 2022-08-08 05:28:53-04:00  academiccoordinator@ritrjpm.ac.in  sent
# 2022-08-10 03:30:04-04:00  academiccoordinator@ritrjpm.ac.in  sent
# 2022-08-05 07:08:25-04:00  academiccoordinator@ritrjpm.ac.in  sent
# 2022-08-22 01:51:45-04:00  academiccoordinator@ritrjpm.ac.in  sent
# ...                                                      ...   ...
# 2021-12-29 04:10:56-05:00  academiccoordinator@ritrjpm.ac.in  sent
# 2021-12-27 04:26:30-05:00  academiccoordinator@ritrjpm.ac.in  sent
# 2021-12-14 22:05:22-05:00  academiccoordinator@ritrjpm.ac.in  sent
# 2022-02-21 06:44:15-05:00  academiccoordinator@ritrjpm.ac.in  sent
# 2022-08-08 03:56:51-04:00  academiccoordinator@ritrjpm.ac.in  sent
#
#                                         thread  \
# date
# 2022-08-16 01:12:23-04:00  1741293705117655457
# 2022-08-08 05:28:53-04:00  1740585016535255003
# 2022-08-10 03:30:04-04:00  1740319452998108596
# 2022-08-05 07:08:25-04:00  1740319452998108596
# 2022-08-22 01:51:45-04:00  1741839323012155946
# ...                                        ...
# 2021-12-29 04:10:56-05:00  1720471645058724169
# 2021-12-27 04:26:30-05:00  1720287047803523254
# 2021-12-14 22:05:22-05:00  1719032286824048724
# 2022-02-21 06:44:15-05:00  1725373351312909515
# 2022-08-08 03:56:51-04:00  1740569411833821157
#
#                                                                           Cc  \
# date
# 2022-08-16 01:12:23-04:00                                                NaN
# 2022-08-08 05:28:53-04:00  Indhumathi M <indhumathi@ritrjpm.ac.in>, \r\n\...
# 2022-08-10 03:30:04-04:00  Principal <principal@ritrjpm.ac.in>, vice prin...
# 2022-08-05 07:08:25-04:00  Principal <principal@ritrjpm.ac.in>, vice prin...
# 2022-08-22 01:51:45-04:00                                                NaN
# ...                                                                      ...
# 2021-12-29 04:10:56-05:00                                                NaN
# 2021-12-27 04:26:30-05:00            Basarikodi K <basarikodi@ritrjpm.ac.in>
# 2021-12-14 22:05:22-05:00                                                NaN
# 2022-02-21 06:44:15-05:00  Principal <principal@ritrjpm.ac.in>, vice prin...
# 2022-08-08 03:56:51-04:00                                                NaN
#
#                            dayofweek  timeofday  hour  year_int         year
# date
# 2022-08-16 01:12:23-04:00    Tuesday   1.206389     1      2022  2022.624230
# 2022-08-08 05:28:53-04:00     Monday   5.481389     5      2022  2022.602327
# 2022-08-10 03:30:04-04:00  Wednesday   3.501111     3      2022  2022.607803
# 2022-08-05 07:08:25-04:00     Friday   7.140278     7      2022  2022.594114
# 2022-08-22 01:51:45-04:00     Monday   1.862500     1      2022  2022.640657
# ...                              ...        ...   ...       ...          ...
# 2021-12-29 04:10:56-05:00  Wednesday   4.182222     4      2021  2021.993840
# 2021-12-27 04:26:30-05:00     Monday   4.441667     4      2021  2021.988364
# 2021-12-14 22:05:22-05:00    Tuesday  22.089444    22      2021  2021.952772
# 2022-02-21 06:44:15-05:00     Monday   6.737500     6      2022  2022.142368
# 2022-08-08 03:56:51-04:00     Monday   3.947500     3      2022  2022.602327
#
# [276 rows x 10 columns]

# %%
# how many mail sent to others
import matplotlib.pyplot as plt    
plt.figure(figsize=(10,10))
# Group the dataset by the column label
lg = dfs.groupby('label')
# Get values items from group with value sent
se=lg.get_group("sent")

ax=sns.countplot(se['label'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# how many mail received from others

import matplotlib.pyplot as plt    
plt.figure(figsize=(10,10))
# Group the dataset by the column label
lg = dfs.groupby('label')
# Get values items from group with value sent
re=lg.get_group("inbox")

ax=sns.countplot(re['label'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# How many mail sent in week day
counts = se.dayofweek.value_counts(sort=False)
counts.plot(kind='pie')

# %%
# How many mail sent in week day
counts = se.dayofweek.value_counts(sort=False)
counts.plot(kind='bar')

# %%
# How many mail received in week day
counts = re.dayofweek.value_counts(sort=False)
counts.plot(kind='bar')

# %%
import scipy.ndimage
from scipy.interpolate import interp1d
import datetime
plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for ct, dow in enumerate(dfs.dayofweek.cat.categories):
  df_r = received[received['dayofweek']==dow]
  weights = np.ones(len(df_r)) / len(received)
  wfun = lambda x: weights
  plot_number_perdhour_per_year(df_r, ax, dt=1, smooth=True, color=f'C{ct}', alpha=0.8, lw=3, label=dow, weight_fun=wfun)
  df_s = sent[sent['dayofweek']==dow]
  weights = np.ones(len(df_s)) / len(sent)
  wfun = lambda x: weights
  plot_number_perdhour_per_year(df_s, ax, dt=1, smooth=True, color=f'C{ct}', alpha=0.8, lw=2, label=dow, ls='--', weight_fun=wfun)

ax.set_ylabel('Fraction of weekly emails per hour')
plt.legend(loc='upper left')

# %%
#Most frequently used words

# %%
from wordcloud import WordCloud
df_no_arxiv = dfs[dfs['from'] != 'no-reply@arXiv.org']
text = ' '.join(map(str, sent['subject'].values))
from wordcloud import WordCloud
df_no_arxiv = dfs[dfs['from'] != 'no-reply@arXiv.org']
text = ' '.join(map(str, sent['subject'].values))

# %%
#plot the word cloud:
stopwords = ['Re', 'Fwd', '3A_']
wrd = WordCloud(width=700, height=480, margin=0, collocations=False)
for sw in stopwords:
  wrd.stopwords.add(sw)
wordcloud = wrd.generate(text)
plt.figure(figsize=(25,15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
